# %% [markdown]
# <a href="https://colab.research.google.com/github/Fernarthit/data_viz_2022/blob/main/Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Project ทำ Dashboard ของ Data Covid (ตั้งแต่วันที่ 12/01/2020 - 15/03/2022) เล่ามุมมองที่เราเลือกเอง + ใช้ข้อมูลภูมิภาค + ข้อมูลอื่นที่เลือกเอง ซึ่งข้อมูลที่เลือกเองคือ  ข้อมูลสถิติการรับรองและสถานะการรับรองของสถานพยาบาลตามมาตรฐาน HA ขั้น 1-3 และ Advanced-HA

# %% [markdown]
# #DataCovid1 ตั้งแต่วันที่ 12/01/2021 ถึง 12/08/2021

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
path = '/content/drive/My Drive/Project_dataviz'

# %%
data_file_path = os.path.join(path,'DATACOVID_1.csv')    
data1 = pd.read_csv(data_file_path)  
data1
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# ...

# %% [markdown]
# #DataCovid2 ตั้งแต่วันที่ 12/08/2021 ถึง 25/10/2021

# %%
data_file_path = os.path.join(path,'DATACOVID_2.csv')    
data2 = pd.read_csv(data_file_path)  
data2
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# #DataCovid3 ตั้งแต่วันที่ 26/10/2021 ถึง 27/02/2022

# %%
data_file_path = os.path.join(path,'DATACOVID_3.csv')   
data3 = pd.read_csv(data_file_path)  
data3_1 =  data3.drop('Unnamed: 11', axis=1) #ลบ Unnamed:11
data3_1
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %% [markdown]
# #DataCovid4 ตั้งแต่วันที่ 28/2/2022 - 15/3/2022

# %%
data_file_path = os.path.join(path,'DATACOVID_4.csv')   
data4 = pd.read_csv(data_file_path)  
data4
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# #ข้อมูลที่เลือก
# #ข้อมูลสถิติการรับรองและสถานะการรับรองของสถานพยาบาลตามมาตรฐาน HA ขั้น 1-3 และ Advanced-HA

# %%
data_file_path = os.path.join(path,'ข้อมูลสถิติการรับรองและสถานะการรับรองของสถานพยาบาลตามมาตรฐาน HA ขั้น 1-3 และ Advanced-HA.csv')    
data2_1 = pd.read_csv(data_file_path)  
data2_1
# Out:
#                                                     No.  \
# 0                                                     1
# 1                                                     2
# 2                                                     3
# 3                                                     4
# 4                                                     5
# ...                                                 ...
# 1473                                               1474
# 1474                                                NaN
# 1475                                           หมายเหตุ
# 1476  สถานะขั้นปัจจุบันที่มีตัวอักษร e (expired)  = ...
# 1477  สถานะขั้นปัจจุบัน r  (Re-Accreditation ) =  โร...
#
#                                                     เขต        จังหวัด  \
# 0                                                     1       เชียงราย
# 1                                                     1       เชียงราย
# 2                                                     1       เชียงราย
# ...

# %% [markdown]
# #รวมData Covid (ตั้งแต่วันที่ 12/01/2020 - 15/03/2022)

# %%
data = pd.concat([data1,data2,data3_1,data4]) 
data
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 357076  3226693     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357077  3226694     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357078  3226695     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357079  3226696     15/3/2022     14/3/2022   ชาย   NaN  NaN         NaN
# 357080  3226697     15/3/2022     14/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# ###ลบค่า Missing ของ DataCovid ตั้งแต่วันที่ 12/01/2020 - 15/03/2022

# %%
datadrop = data.dropna() #ลบข้อมูลที่มี NaN
datadrop
# Out:
#             No. announce_date Notified date   sex   age Unit     nationality  \
# 47           48      6/3/2020      4/3/2020   ชาย  43.0   ปี  United Kingdom
# 124         125      6/3/2021      5/3/2021  หญิง  55.0   ปี        Thailand
# 161         162     17/3/2020     21/3/2020   ชาย  14.0   ปี        Thailand
# 181         182     18/3/2020     15/3/2020   ชาย  33.0   ปี        Thailand
# 186         187     18/3/2020     16/3/2020   ชาย  36.0   ปี        Thailand
# ...         ...           ...           ...   ...   ...  ...             ...
# 357022  3226639     15/3/2022     14/3/2022  หญิง  66.0   ปี        Thailand
# 357023  3226640     15/3/2022     14/3/2022  หญิง  49.0   ปี        Thailand
# 357024  3226641     15/3/2022     14/3/2022  หญิง  19.0   ปี        Thailand
# 357025  3226642     15/3/2022     14/3/2022   ชาย  66.0   ปี        Thailand
# 357026  3226643     15/3/2022     14/3/2022   ชาย  46.0   ปี        Thailand
#
# ...

# %%
set(datadrop['province_of_onset'])
# Out:
# {'\tประจวบคีรีขันธ์',
#  'USA',
#  'กทม.',
#  'กบินทร์บุรี',
#  'กระบี่',
#  'กระบี่ี่',
#  'กรุงเทพ',
#  'กรุงเทพมหานคร',
#  'กรุงเทพมหานคร.',
#  'กรุงเทพมหานคร. / พระนครศรีอยุธยา',
#  'กรุงเทพมหานคร. / ศรีสะเกษ',
#  'กรุงเทพฯ',
#  'กะทู้',
#  'กัมพูชา',
#  'กาญจนบุรี',
#  'กาญจบุรี',
#  'กาญนบุรี',
#  'กาฬสิน',
#  'กาฬสินธุ์',
#  'กาฬสินธุ์\xa0',
#  'กำแพง',
#  'กำแพงเพชร',
#  'กำแพงเพชร\xa0',
#  'กําแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'ขัยภูมิ',
#  'ขานุวรลักษณ์บุรี',
#  'คนไทยเดินทางกลับจากต่างประเทศ',
#  'คลองเตย',
#  'จ.กรุงเทพมหานคร',
#  'จ.ภูเก็ต',
#  'จ.ราชบุรี',
#  'จังหวัดสมุทรสาคร',
#  'จันทบุรี',
#  'ฉะเชองเทราร',
#  'ฉะเชิงเทรา',
#  'ชมพร',
#  'ชลบุรี',
#  'ชลบุรี\xa0',
#  'ชอนแก่น',
#  'ชัยนาถ',
#  'ชัยนาท',
#  'ชัยบาดาล',
#  'ชัยภูมิ',
#  'ชัยภูมิ\xa0',
#  'ชุมพร',
#  'ชุุุมพร',
#  'ดอนมดแดง',
#  'ดินแดง',
#  'ตรัง',
#  'ตรััง',
#  'ตราด',
#  'ตราด\xa0',
#  'ตาก',
#  'ต่างจังหวัด',
#  'ทุ่งเสลี่ยม',
#  'นครนปฐม',
#  'นครนายก',
#  'นครปฐม',
#  'นครปฐม\xa0',
# ...

# %%
datadrop.isnull().any() #เช็ค Missing False คือ ไม่มี
# Out:
# No.                      False
# announce_date            False
# Notified date            False
# sex                      False
# age                      False
# Unit                     False
# nationality              False
# province_of_isolation    False
# risk                     False
# province_of_onset        False
# district_of_onset        False
# dtype: bool

# %% [markdown]
# ###ลบค่า Missing ของข้อมูลสถิติการรับรองและสถานะการรับรองของสถานพยาบาลตามมาตรฐาน HA ขั้น 1-3 และ Advanced-HA

# %%
datadrop1 = data2_1.dropna() #ลบ Missing
datadrop1
# Out:
#        No. เขต        จังหวัด  \
# 1        2   1       เชียงราย
# 2        3   1       เชียงราย
# 4        5   1       เชียงราย
# 5        6   1       เชียงราย
# 6        7   1       เชียงราย
# ...    ...  ..            ...
# 1468  1469  13  กรุงเทพมหานคร
# 1469  1470  13  กรุงเทพมหานคร
# 1470  1471  13  กรุงเทพมหานคร
# 1471  1472  13  กรุงเทพมหานคร
# 1473  1474  13  กรุงเทพมหานคร
#
#                                               โรงพยาบาล   H Code  \
# 1                                            แม่ฟ้าหลวง  11200.0
# 2                                                  เทิง  11189.0
# 4                                              เชียงแสน  11193.0
# 5                                เกษมราษฎร์ ศรีบุรินทร์  12026.0
# 6                                                แม่จัน  11192.0
# ...                                                 ...      ...
# 1468                           สถาบันกัลยาณ์ราชนครินทร์  11597.0
# 1469                            ทั่วไปขนาดใหญ่วิชัยยุทธ  11714.0
# ...

# %%
datadrop1.isnull().any() #เช็คจำนวน Missimg False คือ ไม่มี
# Out:
# No.             False
# เขต             False
# จังหวัด         False
# โรงพยาบาล       False
# H Code          False
# สังกัด          False
# ชนิดรพ.         False
# ขั้นปัจจุบัน    False
# วันรับรอง       False
# วันหมดอายุ      False
# dtype: bool
